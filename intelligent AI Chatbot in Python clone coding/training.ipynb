# %%
# train chatbot

import random
import json
import pickle
import numpy as np
import nltk
nltk.download('punkt')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
# work working worked works == same word 이걸 해주는게 WordNetLemmatizer

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD

lemmatizer = WordNetLemmatizer()

intents = json.loads(open('intents.json').read())

words = []
classes = []
documents = []
ignore_letters = ['?', '!', '.', ',']

for intent in intents['intents']:
    for pattern in intent['patterns']:
        word_list = nltk.word_tokenize(pattern)
        words.extend(word_list)
        documents.append((word_list, intent['tag']))
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

print(documents)

words=[lemmatizer.lemmatize(word) for word in words if word not in ignore_letters]
words=sorted(set(words))

classes=sorted(set(classes))

pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))

training=[]
output_empty=[0]*len(classes)

for document in documents:
  bag=[]
  word_patterns=document[0]
  word_patterns=[lemmatizer.lemmatize(word.lower()) for word in word_patterns]
  for word in words:
    bag.append(1) if word in word_patterns else bag.append(0)

  output_row=list(output_empty)
  output_row[classes.index(document[1])] = 1
  training.append([bag, output_row])

random.shuffle(training)
training=np.array(training)

train_x=list(training[:,0])
train_y=list(training[:,1])

model=Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]),activation='softmax'))

sgd=SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy',optimizer=sgd,metrics=['accuracy'])

hist=model.fit(np.array(train_x),np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbotmodel.h5',hist)
print("Done")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [(['hello'], 'greetings'), (['hey'], 'greetings'), (['hi'], 'greetings'), (['good', 'day'], 'greetings'), (['Greetings'], 'greetings'), (['what', "'s", 'up', '?'], 'greetings'), (['how', 'is', 'it', 'going', '?'], 'greetings'), (['cya'], 'goodbye'), (['See', 'you', 'later'], 'goodbye'), (['Goodbye'], 'goodbye'), (['I', 'am', 'Leaving'], 'goodbye'), (['Have', 'a', 'Good', 'day'], 'goodbye'), (['bye'], 'goodbye'), (['cao'], 'goodbye'), (['see', 'ya'], 'goodbye'), (['how', 'old'], 'age'), (['how', 'old', 'is', 'florian'], 'age'), (['what', 'is', 'your', 'age'], 'age'), (['how', 'old', 'are', 'you'], 'age'), (['age', '?'], 'age'), (['what', 'is', 'your', 'name'], 'name'), (['what', 'should', 'I', 'call', 'you'], 'name'), (['whats', 'your', 'name', '?'], 'name'), (['who', 'are', 'you', '?'], 'name'), (['Can', 'you', 'tell', 'me', 'your', 'name', '?'], 'name'), (['I', "'d", 'like', 'to', 'buy', 'something'], 'shop'), (['what', 'are', 'your', 'products', '?'], 'shop'), (['what', 'do', 'you', 'recommend', '?'], 'shop'), (['What', 'are', 'you', 'selling', '?'], 'shop'), (['when', 'are', 'you', 'guys', 'open'], 'hours'), (['what', 'are', 'your', 'hours'], 'hours'), (['hours', 'of', 'operation'], 'hours'), (['what', 'stocks', 'do', 'I', 'own', '?'], 'stocks'), (['how', 'are', 'my', 'shares', '?'], 'stocks'), (['what', 'companies', 'am', 'I', 'investing', 'in', '?'], 'stocks'), (['what', 'am', 'I', 'doing', 'in', 'the', 'markets', '?'], 'stocks')]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:59: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# Epoch 1/200
# 8/8 [==============================] - 1s 4ms/step - loss: 1.9735 - accuracy: 0.1389
# Epoch 2/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.9311 - accuracy: 0.1944
# Epoch 3/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.9163 - accuracy: 0.1944
# Epoch 4/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.8969 - accuracy: 0.2222
# Epoch 5/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.8309 - accuracy: 0.2778
# Epoch 6/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.6901 - accuracy: 0.3889
# Epoch 7/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.6491 - accuracy: 0.3611
# Epoch 8/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.5876 - accuracy: 0.5000
# Epoch 9/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.5828 - accuracy: 0.3333
# Epoch 10/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.5340 - accuracy: 0.4722
# Epoch 11/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.2938 - accuracy: 0.5556
# Epoch 12/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.3533 - accuracy: 0.5000
# Epoch 13/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1268 - accuracy: 0.6111
# Epoch 14/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0959 - accuracy: 0.6389
# Epoch 15/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.9386 - accuracy: 0.7222
# Epoch 16/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.9317 - accuracy: 0.7778
# Epoch 17/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.7937 - accuracy: 0.8333
# Epoch 18/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.9574 - accuracy: 0.6111
# Epoch 19/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.8340 - accuracy: 0.7500
# Epoch 20/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8127 - accuracy: 0.7222
# Epoch 21/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.7880 - accuracy: 0.6667
# Epoch 22/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6923 - accuracy: 0.7222
# Epoch 23/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4571 - accuracy: 0.9167
# Epoch 24/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.7266 - accuracy: 0.7778
# Epoch 25/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5567 - accuracy: 0.8333
# Epoch 26/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5635 - accuracy: 0.9167
# Epoch 27/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5074 - accuracy: 0.8889
# Epoch 28/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5284 - accuracy: 0.8056
# Epoch 29/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3459 - accuracy: 0.9167
# Epoch 30/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4058 - accuracy: 0.8611
# Epoch 31/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2658 - accuracy: 0.9722
# Epoch 32/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4493 - accuracy: 0.8889
# Epoch 33/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3184 - accuracy: 0.8611
# Epoch 34/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3337 - accuracy: 0.9167
# Epoch 35/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3896 - accuracy: 0.8889
# Epoch 36/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2617 - accuracy: 0.9444
# Epoch 37/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3500 - accuracy: 0.8611
# Epoch 38/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3443 - accuracy: 0.8889
# Epoch 39/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2921 - accuracy: 0.9167
# Epoch 40/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4735 - accuracy: 0.8333
# Epoch 41/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2334 - accuracy: 0.9444
# Epoch 42/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2009 - accuracy: 0.9444
# Epoch 43/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2294 - accuracy: 0.9167
# Epoch 44/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3725 - accuracy: 0.9167
# Epoch 45/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3218 - accuracy: 0.8889
# Epoch 46/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2379 - accuracy: 0.9444
# Epoch 47/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3274 - accuracy: 0.9444
# Epoch 48/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2140 - accuracy: 0.8889
# Epoch 49/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1581 - accuracy: 0.9167
# Epoch 50/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2303 - accuracy: 0.9444
# Epoch 51/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2275 - accuracy: 0.9444
# Epoch 52/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3979 - accuracy: 0.8056
# Epoch 53/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1504 - accuracy: 0.9444
# Epoch 54/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2173 - accuracy: 0.9167
# Epoch 55/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2871 - accuracy: 0.9444
# Epoch 56/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2748 - accuracy: 0.9444
# Epoch 57/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1884 - accuracy: 0.9722
# Epoch 58/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1602 - accuracy: 0.9444
# Epoch 59/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1687 - accuracy: 0.9444
# Epoch 60/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1439 - accuracy: 0.9722
# Epoch 61/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2096 - accuracy: 0.9444
# Epoch 62/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1112 - accuracy: 0.9722
# Epoch 63/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2681 - accuracy: 0.9167
# Epoch 64/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1699 - accuracy: 0.9167
# Epoch 65/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1413 - accuracy: 0.9722
# Epoch 66/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1883 - accuracy: 0.9722
# Epoch 67/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1366 - accuracy: 0.9722
# Epoch 68/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0923 - accuracy: 1.0000
# Epoch 69/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1444 - accuracy: 0.9444
# Epoch 70/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0975 - accuracy: 0.9722
# Epoch 71/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2144 - accuracy: 0.9167
# Epoch 72/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1497 - accuracy: 0.9722
# Epoch 73/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0845 - accuracy: 0.9722
# Epoch 74/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0842 - accuracy: 0.9722
# Epoch 75/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1388 - accuracy: 0.9722
# Epoch 76/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1109 - accuracy: 0.9722
# Epoch 77/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2728 - accuracy: 0.8889
# Epoch 78/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0913 - accuracy: 1.0000
# Epoch 79/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0663 - accuracy: 1.0000
# Epoch 80/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1648 - accuracy: 0.9167
# Epoch 81/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1414 - accuracy: 0.9444
# Epoch 82/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1260 - accuracy: 1.0000
# Epoch 83/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1539 - accuracy: 0.9444
# Epoch 84/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0689 - accuracy: 0.9722
# Epoch 85/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1117 - accuracy: 0.9444
# Epoch 86/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0998 - accuracy: 0.9722
# Epoch 87/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1656 - accuracy: 0.9167
# Epoch 88/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0974 - accuracy: 0.9722
# Epoch 89/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1478 - accuracy: 0.9444
# Epoch 90/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0586 - accuracy: 1.0000
# Epoch 91/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1382 - accuracy: 0.9722
# Epoch 92/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1070 - accuracy: 0.9722
# Epoch 93/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1714 - accuracy: 0.9444
# Epoch 94/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1082 - accuracy: 0.9444
# Epoch 95/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1032 - accuracy: 0.9444
# Epoch 96/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0544 - accuracy: 1.0000
# Epoch 97/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0907 - accuracy: 0.9444
# Epoch 98/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1273 - accuracy: 0.9444
# Epoch 99/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1010 - accuracy: 0.9444
# Epoch 100/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0993 - accuracy: 0.9722
# Epoch 101/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1367 - accuracy: 0.9444
# Epoch 102/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0954 - accuracy: 0.9722
# Epoch 103/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0718 - accuracy: 1.0000
# Epoch 104/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0335 - accuracy: 1.0000
# Epoch 105/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1065 - accuracy: 0.9444
# Epoch 106/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3183 - accuracy: 0.9444
# Epoch 107/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0909 - accuracy: 0.9444
# Epoch 108/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0909 - accuracy: 0.9722
# Epoch 109/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1408 - accuracy: 0.9722
# Epoch 110/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0829 - accuracy: 0.9444
# Epoch 111/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0759 - accuracy: 1.0000
# Epoch 112/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0745 - accuracy: 0.9722
# Epoch 113/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0808 - accuracy: 0.9722
# Epoch 114/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1606 - accuracy: 0.9444
# Epoch 115/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0791 - accuracy: 0.9722
# Epoch 116/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1289 - accuracy: 0.9444
# Epoch 117/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1131 - accuracy: 0.9722
# Epoch 118/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2152 - accuracy: 0.9722
# Epoch 119/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1780 - accuracy: 0.9444
# Epoch 120/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1574 - accuracy: 0.9167
# Epoch 121/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1205 - accuracy: 0.9722
# Epoch 122/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0815 - accuracy: 0.9444
# Epoch 123/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1469 - accuracy: 0.9722
# Epoch 124/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2080 - accuracy: 0.9444
# Epoch 125/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0877 - accuracy: 0.9722
# Epoch 126/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2102 - accuracy: 0.9167
# Epoch 127/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1102 - accuracy: 0.9722
# Epoch 128/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0470 - accuracy: 0.9722
# Epoch 129/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0916 - accuracy: 0.9722
# Epoch 130/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0746 - accuracy: 0.9722
# Epoch 131/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1243 - accuracy: 0.9722
# Epoch 132/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0813 - accuracy: 0.9722
# Epoch 133/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1058 - accuracy: 0.9444
# Epoch 134/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0885 - accuracy: 0.9722
# Epoch 135/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0612 - accuracy: 0.9722
# Epoch 136/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0495 - accuracy: 1.0000
# Epoch 137/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0879 - accuracy: 0.9444
# Epoch 138/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0842 - accuracy: 1.0000
# Epoch 139/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0360 - accuracy: 1.0000
# Epoch 140/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0943 - accuracy: 0.9722
# Epoch 141/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0717 - accuracy: 0.9444
# Epoch 142/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0527 - accuracy: 0.9722
# Epoch 143/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2266 - accuracy: 0.8611
# Epoch 144/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1418 - accuracy: 0.9722
# Epoch 145/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1601 - accuracy: 0.9722
# Epoch 146/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1805 - accuracy: 0.9167
# Epoch 147/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1017 - accuracy: 0.9722
# Epoch 148/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0550 - accuracy: 0.9722
# Epoch 149/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1586 - accuracy: 0.9167
# Epoch 150/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0597 - accuracy: 1.0000
# Epoch 151/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0586 - accuracy: 1.0000
# Epoch 152/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0613 - accuracy: 0.9722
# Epoch 153/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1555 - accuracy: 0.9722
# Epoch 154/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0769 - accuracy: 0.9722
# Epoch 155/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0796 - accuracy: 0.9722
# Epoch 156/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1061 - accuracy: 0.9167
# Epoch 157/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1468 - accuracy: 0.9444
# Epoch 158/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1224 - accuracy: 0.9722
# Epoch 159/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0985 - accuracy: 0.9167
# Epoch 160/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1038 - accuracy: 0.9444
# Epoch 161/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1159 - accuracy: 0.9722
# Epoch 162/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0888 - accuracy: 0.9444
# Epoch 163/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0984 - accuracy: 0.9722
# Epoch 164/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0778 - accuracy: 0.9722
# Epoch 165/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0692 - accuracy: 0.9722
# Epoch 166/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0736 - accuracy: 0.9722
# Epoch 167/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0606 - accuracy: 0.9722
# Epoch 168/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0632 - accuracy: 0.9444
# Epoch 169/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1098 - accuracy: 0.9167
# Epoch 170/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0484 - accuracy: 0.9722
# Epoch 171/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0801 - accuracy: 0.9444
# Epoch 172/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0867 - accuracy: 0.9444
# Epoch 173/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0989 - accuracy: 0.9444
# Epoch 174/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0739 - accuracy: 0.9722
# Epoch 175/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0835 - accuracy: 0.9722
# Epoch 176/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0685 - accuracy: 0.9444
# Epoch 177/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1520 - accuracy: 0.9167
# Epoch 178/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0821 - accuracy: 0.9722
# Epoch 179/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0686 - accuracy: 0.9444
# Epoch 180/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0616 - accuracy: 0.9722
# Epoch 181/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1020 - accuracy: 0.9722
# Epoch 182/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0714 - accuracy: 0.9722
# Epoch 183/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0891 - accuracy: 0.9722
# Epoch 184/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0783 - accuracy: 0.9722
# Epoch 185/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0529 - accuracy: 0.9722
# Epoch 186/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0820 - accuracy: 0.9722
# Epoch 187/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0975 - accuracy: 0.9444
# Epoch 188/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0640 - accuracy: 0.9722
# Epoch 189/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0429 - accuracy: 0.9722
# Epoch 190/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0473 - accuracy: 1.0000
# Epoch 191/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0275 - accuracy: 1.0000
# Epoch 192/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0414 - accuracy: 0.9722
# Epoch 193/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0702 - accuracy: 0.9722
# Epoch 194/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0494 - accuracy: 0.9722
# Epoch 195/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0618 - accuracy: 0.9722
# Epoch 196/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1187 - accuracy: 0.9444
# Epoch 197/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0656 - accuracy: 0.9444
# Epoch 198/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1120 - accuracy: 0.9444
# Epoch 199/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0834 - accuracy: 0.9444
# Epoch 200/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1043 - accuracy: 0.9444
# Done

# %%
# build chatbot

import random
import json
import pickle
import numpy as np

import nltk
nltk.download('punkt')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer

from tensorflow.keras.models import load_model

lemmatizer = WordNetLemmatizer()
intents=json.loads(open('intents.json').read())

words=pickle.load(open('words.pkl','rb'))
classes=pickle.load(open('classes.pkl','rb'))
model=load_model('chatbotmodel.h5')

def clean_up_sentence(sentence):
  sentence_words=nltk.word_tokenize(sentence)
  sentence_words=[lemmatizer.lemmatize(word) for word in sentence_words]
  return sentence_words

def bag_of_words(sentence):
  sentence_words=clean_up_sentence(sentence)
  bag=[0]*len(words)
  for w in sentence_words:
    for i, word in enumerate(words):
      if word==w: #else: 0
        bag[i]=1
  return np.array(bag)

def predict_class(sentence):
  bow=bag_of_words(sentence)
  res=model.predict(np.array([bow]))[0]
  ERROR_THRESHOLD=0.25
  results=[[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]

  results.sort(key=lambda x: x[1], reverse=True)
  return_list=[]
  for r in results:
    return_list.append({'intent': classes[r[0]], 'probability': str(r[1])})
  return return_list

def get_response(intents_list,intents_json):
  tag = intents_list[0]['intent']
  list_of_intents=intents_json['intents']
  for i in list_of_intents:
    if i['tag']==tag:
      result=random.choice(i['responses'])
      break
  return result

print("GO! Bot is running!")

while True:
  message=input("")
  ints=predict_class(message)
  res=get_response(ints,intents)
  print(res)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# GO! Bot is running!
# hey
# Hello!
# hi
# Hello!
# how are you?
# 22years!
# how are you?
# 22years!
# what is your name my friend!!
# You can call me Neural!.
# what are my stoks doing?
# You own the following shares: ABBV, AAPL, FB, NVDA and an ETF of the S&P 500 Index!
# goodbye
# Talk to you later
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     624         """
# --> 625         parts = [self.recv(flags, copy=copy, track=track)]
#     626         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-b1f4cb78d0ef> in <module>()
#      58
#      59 while True:
# ---> 60   message=input("")
#      61   ints=predict_class(message)
#      62   res=get_response(ints,intents)
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:
